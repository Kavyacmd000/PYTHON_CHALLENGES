# %% [markdown]
# **Kavya SampathKumar   **   PYTHON ASSIGNMENT 2

# %% [markdown]
# 1. List Creation: a. Create a list named age_list with fi ve integer elements. For eg., [24, 25, 26, 27, 28]

# %%
age_list=[24,25,26,27,28]
print(age_list)
# Out:
# [24, 25, 26, 27, 28]

# %% [markdown]
#  b. Create a list named name_list with five string elements.

# %%
name_list=["Kavya","Rukmani","Sampath","Kumar","Samruka"]
print(name_list)
# Out:
# ['Kavya', 'Rukmani', 'Sampath', 'Kumar', 'Samruka']

# %% [markdown]
# 2. List Operations / Modifications: a. Append the string "Yazhini" to name_list.

# %%
name_list.append("Yazhini")
print(name_list)
# Out:
# ['Kavya', 'Rukmani', 'Sampath', 'Kumar', 'Samruka', 'Yazhini']

# %% [markdown]
# b. Insert the element 30 at index 2 in age_list.

# %%
age_list.insert(2,30)
print(age_list)
# Out:
# [24, 25, 30, 26, 27, 28]

# %% [markdown]
# c. Remove the string "Yazhini" from name_list.

# %%
name_list.remove("Yazhini")
print(name_list)
# Out:
# ['Kavya', 'Rukmani', 'Sampath', 'Kumar', 'Samruka']

# %% [markdown]
# d. Pop the last element from age_list.

# %%
age_list.pop()
print(age_list)
# Out:
# [24, 25, 30, 26, 27]

# %% [markdown]
# e. Extend the age_list with additional ages [29, 30, 26].

# %%
age_list.extend([29,30,26])
print(age_list)
# Out:
# [24, 25, 30, 26, 27, 29, 30, 26]

# %% [markdown]
# f. Sort age_list in descending order.

# %%
age_list.sort(reverse=True)
print(age_list)
# Out:
# [30, 30, 29, 27, 26, 26, 25, 24]

# %% [markdown]
# g. Find Max age, Min age and sum of all ages from age_list.

# %%
max(age_list)
# Out:
# 30

# %%
min(age_list)
# Out:
# 24

# %%
sum(age_list)
# Out:
# 217

# %% [markdown]
# 3. Accessing List Elements:
# a. Print the first element of name_list.

# %%
name_list[0]
# Out:
# 'Kavya'

# %% [markdown]
# b. Print the last element of name_list.

# %%
len(name_list)
# Out:
# 5

# %%
print(name_list)
# Out:
# ['Kavya', 'Rukmani', 'Sampath', 'Kumar', 'Samruka']

# %%
name_list[-1]
# Out:
# 'Samruka'

# %% [markdown]
# c. Print the elements from index 2 to index 4 in name_list.

# %%
name_list[2:]
# Out:
# ['Sampath', 'Kumar', 'Samruka']

# %% [markdown]
# d. Print the elements of name_list in reverse order.

# %%
name_list[-1:-6:-1]
# Out:
# ['Samruka', 'Kumar', 'Sampath', 'Rukmani', 'Kavya']

# %% [markdown]
# Dictionary (Creation, Modification and Access):
#  a. Create a dictionary named student_marks that maps the names of five students to their marks (use scale of from 0 to 100).
#
# > Add blockquote

# %%
student_marks={
                "Abi":90,
                "Anu":80,
                "Asha":70,
                "Basha":60,
                "Bharathi":50
               }
print(student_marks)
# Out:
# {'Abi': 90, 'Anu': 80, 'Asha': 70, 'Basha': 60, 'Bharathi': 50}

# %%
type(student_marks)
# Out:
# dict

# %% [markdown]
# b. Access and print the mark of a specific student, of your choice.

# %%
print(student_marks["Abi"])
# Out:
# 90

# %% [markdown]
# c. Add a new student "Janani" with a mark of 80 to the student_marks dictionary.

# %%
student_marks['Janani']=80
student_marks
# Out:
# {'Abi': 90, 'Anu': 80, 'Asha': 70, 'Basha': 60, 'Bharathi': 50, 'Janani': 80}

# %% [markdown]
# d. Update the mark of any one older student to 82.

# %%
student_marks.update({"Abi":20})
student_marks
# Out:
# {'Abi': 20, 'Anu': 80, 'Asha': 70, 'Basha': 60, 'Bharathi': 50, 'Janani': 80}

# %% [markdown]
# e. Use the keys(), values(), and items() methods to print all keys, values, and key-value pairs in the student_marks dictionary.

# %%
student_marks.keys()
# Out:
# dict_keys(['Abi', 'Anu', 'Asha', 'Basha', 'Bharathi', 'Janani'])

# %%
student_marks.values()
# Out:
# dict_values([20, 80, 70, 60, 50, 80])

# %%
student_marks.items()
# Out:
# dict_items([('Abi', 20), ('Anu', 80), ('Asha', 70), ('Basha', 60), ('Bharathi', 50), ('Janani', 80)])

# %% [markdown]
# Sets (Operations):
# a. Create a set called my_set with following values: ['a','e','i','o','u','a','a','i']
# Analyse the output and provide explanation for the same.

# %%
vowels=["a","e","i","o","u","a","a","i"]
my_set=set(vowels)
print(my_set) ''' {'o', 'e', 'i', 'u', 'a'} answer produced since set does not allow duplicate values and unordered one'''
# Out:
# {'o', 'e', 'i', 'u', 'a'}

# %% [markdown]
# b. Attempt to change the value of my_set[4] = 's'. If code throws an error, provide an explanation.

# %%
my_set[4]="s"
print(my_set) ''' TypeError: 'set' object does not support item assignment because set is an unindex one'''
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_5046/2192794591.py in <cell line: 0>()
# ----> 1 my_set[4]="s"
#       2 print(my_set)
#
# TypeError: 'set' object does not support item assignment

# %% [markdown]
# c. Create two sets: set1 with values: {1, 3, 5, 7, 9} set2 with values: {2, 3, 5, 8, 10}

# %%
set1={1,3,5,7,9}
set2={2,3,5,8,10}
print(set1)
# Out:
# {1, 3, 5, 7, 9}

# %%
print(set2)
# Out:
# {2, 3, 5, 8, 10}

# %% [markdown]
# d. Compute and print the union and intersection of set1 and set2.

# %%
u=set1.union(set2)
print(u)
# Out:
# {1, 2, 3, 5, 7, 8, 9, 10}

# %%
i=set1&set2
i
# Out:
# {3, 5}

# %% [markdown]
# Operators & Conditional Statements :
# (IF, ELIF, ELSE)
# Performance Category Program:
# 1. Prompt user for Input. Score range should be from 0 to 10 (both inclusive).
# 2. Find the performance category based on the input score using following criteria:
# a. Above Average: Score greater than 7
# b. Average: Score between 4 and 7(both inclusive)
# c. Below Average: Score lesser than 4
# 3. Output: Print the Performance category
# 4. Additional Step: You can give a prompt of your choice to each category.
# For eg: If score below average “Need to Improve your performance, consistent practice will lead to better results”.

# %%
Score_Range=int(input("Enter the Score Range from 0 to 10 : "))
if Score_Range>7:
  print("Above Average : Excellent! ,Keep It Up")
elif Score_Range>=4 and Score_Range<=7:
  print("Average : Good effort! Keep practicing, there's room for improvement.")
else:
  print("Below Average : Need to Improve your performance, consistent practice will lead to better results ")
# Out:
# Enter the Score Range from 0 to 10 : 9
# Above Average : Excellent! ,Keep It Up
